# %%
import pandas as pd

data = pd.read_csv('AmesHousing.csv', sep =' ')

# %%
data.head()
# Out:
#                                       Order\tPID\tMS      SubClass\tMS  \
# 0  1\t0526301100\t020\tRL\t141\t31770\tPave\tNA\t...  \tNormal\t215000
# 1  2\t0526350040\t020\tRH\t80\t11622\tPave\tNA\tR...  \tNormal\t105000
# 2  3\t0526351010\t020\tRL\t81\t14267\tPave\tNA\tI...          Sdng\tWd
# 3  4\t0526353030\t020\tRL\t93\t11160\tPave\tNA\tR...  \tNormal\t244000
# 4  5\t0527105010\t060\tRL\t74\t13830\tPave\tNA\tI...  \tNormal\t189900
#
#                                          Zoning\tLot     Frontage\tLot  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2  Sdng\tBrkFace\t108\tTA\tTA\tCBlock\tTA\tTA\tNo...  \tNormal\t172000
# 3                                                NaN               NaN
# 4                                                NaN               NaN
#
#   Area\tStreet\tAlley\tLot  Shape\tLand  Contour\tUtilities\tLot  \
# ...
